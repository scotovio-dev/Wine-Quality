# %% [markdown]
# # Wine Quality

# %% [markdown]
# #### Libraries

# %%
#!pip install pandas
#!pip install Jinja2

# %%
import pandas as pd
from IPython.display import display, HTML

# %% [markdown]
# #### Importing Datasets

# %%
red = pd.read_csv("winequality-red.csv", sep=";")
white = pd.read_csv("winequality-white.csv", sep=";")

# %% [markdown]
# ### EDA

# %%
print("red")
display(red.head())
print("white")
display(white.head())
# Out:
# red
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# white
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %% [markdown]
# #### Nulls

# %%
missing_df = pd.DataFrame({
    'red': red.isna().sum(),
    'white': white.isna().sum()
})

missing_df = missing_df.style.set_caption('Missing Values Summary')
display(missing_df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4a98">
#   <caption>Missing Values Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4a98_level0_col0" class="col_heading level0 col0" >red</th>
#       <th id="T_f4a98_level0_col1" class="col_heading level0 col1" >white</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4a98_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_f4a98_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f4a98_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_f4a98_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_f4a98_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_f4a98_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_f4a98_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_f4a98_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_f4a98_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_f4a98_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_f4a98_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_f4a98_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_f4a98_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row6" class="row_heading level0 row6" >total sulfur dioxide</th>
#       <td id="T_f4a98_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_f4a98_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row7" class="row_heading level0 row7" >density</th>
#       <td id="T_f4a98_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_f4a98_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row8" class="row_heading level0 row8" >pH</th>
#       <td id="T_f4a98_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_f4a98_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row9" class="row_heading level0 row9" >sulphates</th>
#       <td id="T_f4a98_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_f4a98_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row10" class="row_heading level0 row10" >alcohol</th>
#       <td id="T_f4a98_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_f4a98_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f4a98_level0_row11" class="row_heading level0 row11" >quality</th>
#       <td id="T_f4a98_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_f4a98_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
